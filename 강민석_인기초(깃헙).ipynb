# %% [markdown]
# <a href="https://colab.research.google.com/github/kmsgd/2026AI/blob/main/%EA%B0%95%EB%AF%BC%EC%84%9D_%EC%9D%B8%EA%B8%B0%EC%B4%88(%EA%B9%83%ED%97%99).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Github Test')
# Out:
# Github Test

# %%
# !git clone https://github.com/kmsgd/2026-data
# Out:
# fatal: destination path '2026-data' already exists and is not an empty directory.

# %%
ls
# Out:
# 2026-data/  sample_data/

# %%
cd 2026-data
# Out:
# /content/2026-data

# %%
ls
# Out:
# heart_test.csv  README.md
